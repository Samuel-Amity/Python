# %%
# File handling Exception handling Custom modules

# %%
# # File handling

# # REad - r
# Append - a
# Write - W

# %%
f = open('amazon.txt', mode='rt')

# %%
f.closed
# Out:
# False

# %%
f.close()

# %%
f.closed
# Out:
# True

# %%
f = open("amazon.txt")

# %%
f.close()

# %%
# Context Manager - it handles our resources ; with

# %%
with open("amazon.txt") as f:
    ("inside :", f.closed)

print("outside :", f.closed)
# Out:
# outside : True

# %%
with open('flipkart.txt', mode='wt') as f:
    f.closed

# %%
# Fot writing : write()

# %%
with open("BLinkit.txt", "wt") as f:
    r1 = f.write("this file has beeen generated by py. \n")
    r2 = f.write("Blinkit provides 10 minutes delivery")

    print(r1,r2)
# Out:
# 38 36

# %%
with open("BLinkit.txt", "at") as f:
    r3 = f.write("I use blinkit daily. \n")
    r4 = f.write("Blinkit has been aquired by zomato")
    print(r3,r4)
# Out:
# 22 34

# %%
#reading op

# %%
with open("BLinkit.txt") as f:
    data = f.read()
    print(data)
# Out:
# this file has beeen generated by py.
# Blinkit provides 10 minutes deliveryI use blinkit daily.
# Blinkit has been aquired by zomato

# %%
# with open("BLinkit.txt") as f:
#     for in in f:
#         print(i)

# %%
# with open("BLinkit.txt") as f:
#     data_list =

# %%
with open("BLinkit.txt", "wt") as f:
    r1a= f.write("I use blinkit daily. \n")

    print(r3,r4)
# Out:
# 22 34

# %%
with open("BLinkit.txt") as f:
    print(f.read())
# Out:
# I use blinkit daily.

# %%
with open("BLinkit.txt", "wt") as f:
    r1 = f.write("I use blinkit daily. \n")
    r2 = f.write("Blinkit has been aquired by zomato. \n")
    r3 = f.write("we can order from amazon as well. \n")

# %%
with open("BLinkit.txt") as f:
    print(f.read(5))

    print(f.read(10))

    print(f.read(6))

    print(f.tell())
    
    f.seek(14)

    print(f.tell())

    print(f.read(6))

    print(f.tell())
# Out:
# I use
#  blinkit d
# aily.
# 21

# %%
with open("BLinkit.txt") as f:
    print(f.read())

# %%
with open ("BLinkit.txt") as f:
    print(f.read())
# Out:
# I use blinkit daily.
# Blinkit has been aquired by zomato.
# we can order from amazon as well.

# %%
# CHanging the content

# %%
with open('BLinkit.txt') as f:
    data_list = f.readlines()

# %%
data_list
# Out:
# ['I use blinkit daily. \n',
#  'Blinkit has been aquired by zomato. \n',
#  'we can order from amazon as well. \n']

# %%
data_list[1]
# Out:
# 'Blinkit has been aquired by zomato. \n'

# %%
data_list[1] = 'zepto is very new in market'

# %%
data_list
# Out:
# ['I use blinkit daily. \n',
#  'zepto is very new in market',
#  'we can order from amazon as well. \n']

# %%
data_to_write = " ".join(data_list)

# %%
with open('BLinkit.txt', mode='wt') as f:
    f.write(data_to_write)

# %%
with open('BLinkit.txt') as f:
    print(f.read())
# Out:
# I use blinkit daily.
#  zepto is very new in market we can order from amazon as well.

# %%
f = open('mydata.csv', mode='rt')

# %%
data = f.read

# %%
print(data())
# Out:
# sepal_length,sepal_width,petal_length,petal_width,species
# 5.1,3.5,1.4,0.2,setosa
# 4.9,3.0,1.4,0.2,setosa
# 4.7,3.2,1.3,0.2,setosa
# 4.6,3.1,1.5,0.2,setosa
# 5.0,3.6,1.4,0.2,setosa
# 5.4,3.9,1.7,0.4,setosa
# 4.6,3.4,1.4,0.3,setosa
# 5.0,3.4,1.5,0.2,setosa
# 4.4,2.9,1.4,0.2,setosa
# 4.9,3.1,1.5,0.1,setosa
# 5.4,3.7,1.5,0.2,setosa
# 4.8,3.4,1.6,0.2,setosa
# 4.8,3.0,1.4,0.1,setosa
# 4.3,3.0,1.1,0.1,setosa
# 5.8,4.0,1.2,0.2,setosa
# 5.7,4.4,1.5,0.4,setosa
# 5.4,3.9,1.3,0.4,setosa
# 5.1,3.5,1.4,0.3,setosa
# 5.7,3.8,1.7,0.3,setosa
# 5.1,3.8,1.5,0.3,setosa
# 5.4,3.4,1.7,0.2,setosa
# 5.1,3.7,1.5,0.4,setosa
# 4.6,3.6,1.0,0.2,setosa
# 5.1,3.3,1.7,0.5,setosa
# 4.8,3.4,1.9,0.2,setosa
# 5.0,3.0,1.6,0.2,setosa
# 5.0,3.4,1.6,0.4,setosa
# 5.2,3.5,1.5,0.2,setosa
# 5.2,3.4,1.4,0.2,setosa
# 4.7,3.2,1.6,0.2,setosa
# 4.8,3.1,1.6,0.2,setosa
# 5.4,3.4,1.5,0.4,setosa
# 5.2,4.1,1.5,0.1,setosa
# 5.5,4.2,1.4,0.2,setosa
# 4.9,3.1,1.5,0.1,setosa
# 5.0,3.2,1.2,0.2,setosa
# 5.5,3.5,1.3,0.2,setosa
# ...
